# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
datajob = df[df["job_title_short"] == "Data Scientist"].copy()


datajob
# Out:
#        job_title_short                                          job_title  \
# 9       Data Scientist                                  Data Scientist II
# 17      Data Scientist                             Data Science Team Lead
# 19      Data Scientist                                     Data Scientist
# 20      Data Scientist                                     Data Scientist
# 21      Data Scientist  Stage - data scientist – génération ia de donn...
# ...                ...                                                ...
# 785689  Data Scientist                           Data Scientist -50065385
# 785690  Data Scientist                    Customer Master Data Specialist
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
# 785697  Data Scientist                      Data Science Python modelling
# 785725  Data Scientist                                 Analytics Engineer
#
#                              job_location  \
# ...

# %%
from adjustText import adjust_text

# %%
datajob_boom = datajob.explode("job_skills")

datajob_boom

boomboom = datajob_boom.groupby("job_skills").agg(
    skill_count = ("job_skills", "count"),
    median_salary = ("salary_year_avg", "median") 
    )

bleh = boomboom.sort_values(by= 'skill_count', ascending = False).head(10)
texts = []
bleh.plot(kind= "scatter", x = 'skill_count', y = 'median_salary', c="median_salary",              # color based on median salary
    cmap="plasma",                 # choose a color map (e.g. viridis, plasma, coolwarm)
    s=50,                          # size of points
    alpha=0.8,                      # transparency
    edgecolor="k")
plt.title("Skill Count vs Median Salary For Data Scientists")
plt.xlabel("Skill Count")
plt.ylabel("Median Salary")


for i, txt in enumerate(bleh.index):
    texts.append(plt.text(bleh["skill_count"].iloc[i] + 0.1, bleh["median_salary"].iloc[i] + 0.1, txt))

adjust_text(texts, arrowprops=dict(arrowstyle="->", color= 'r', lw=0.7))

ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f"${int(y/1000)}K"))
plt.show()
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad: 'float' = 1.08, h_pad: 'float | None' = None, w_pad: 'float | None' = None, rect: 'tuple[float, float, float, float] | None' = None) -> 'None'>
