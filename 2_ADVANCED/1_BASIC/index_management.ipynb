# %%
import pandas as pd
import numpy as np
from datasets import load_dataset
import matplotlib.pyplot as plt

# %%
#loading dataset 

dataset = load_dataset("lukebarousse/data_jobs")

data_jobs = dataset['train'].to_pandas()

data_jobs ["job_posted_date"] = pd.to_datetime(data_jobs.job_posted_date)

# %%
data_jobs.sample(10)
# Out:
#               job_title_short  \
# 414968          Data Engineer
# 314986         Data Scientist
# 411116         Data Scientist
# 693859          Data Engineer
# 443959  Senior Data Scientist
# 208373       Business Analyst
# 414657          Data Engineer
# 259763      Software Engineer
# 742727         Data Scientist
# 488355          Data Engineer
#
#                                                 job_title  \
# 414968                                      Data Engineer
# 314986                             Static Data Specialist
# 411116                   Workday Services Data Consultant
# 693859                 Data Engineer - Hedge Fund - £200k
# 443959                              Senior Data Scientist
# 208373                                  Reporting Analyst
# 414657                                Staff Data Engineer
# 259763  Senior Data Engineer / Software Engineer - Now...
# 742727                           Data Scientist - Pricing
# ...

# %%
data_jobs.index.dtype
# Out:
# dtype('int64')

# %%
datajobs_australia = data_jobs[data_jobs['job_country'] == "Australia"]

datajobs_australia.reset_index(inplace= True)

datajobs_australia.head(5)
# Out:
#    index       job_title_short                               job_title  \
# 0     90        Data Scientist                          Data Scientist
# 1    501     Software Engineer  Senior Engineer - Platform Engineering
# 2    758  Senior Data Engineer                    Senior Data Engineer
# 3   1178         Data Engineer                    Data Center Engineer
# 4   1278        Cloud Engineer                 Infrastructure Engineer
#
#                       job_location              job_via job_schedule_type  \
# 0                        Australia  via BeBee Australia         Full-time
# 1            Sydney NSW, Australia         via LinkedIn         Full-time
# 2            Sydney NSW, Australia      via Trabajo.org         Full-time
# 3            Sydney NSW, Australia         via LinkedIn         Full-time
# 4  Fortitude Valley QLD, Australia         via LinkedIn         Full-time
#
#    job_work_from_home search_location     job_posted_date  \
# ...

# %%
datajobs_australia.set_index('index', inplace = True)

datajobs_australia
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/l0/k4x186gj0bb144vhk6pmyc3c0000gn/T/ipykernel_92084/586653676.py in ?()
# ----> 1 datajobs_australia.set_index('index', inplace = True)
#       2
#       3 datajobs_australia
#
# /opt/anaconda3/envs/python_course/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6140                     if not found:
#    6141                         missing.append(col)
#    6142
#    6143         if missing:
# -> 6144             raise KeyError(f"None of {missing} are in the columns")
#    6145
#    6146         if inplace:
#    6147             frame = self
#
# KeyError: "None of ['index'] are in the columns"

# %%
# Filter for Australia
datajobs_australia = data_jobs[data_jobs['job_country'] == "Australia"].copy()

# Reset index so it starts from 0
datajobs_australia.reset_index( inplace=True)

# Display first 5 rows
datajobs_australia.head()
# Out:
#    index       job_title_short                               job_title  \
# 0     90        Data Scientist                          Data Scientist
# 1    501     Software Engineer  Senior Engineer - Platform Engineering
# 2    758  Senior Data Engineer                    Senior Data Engineer
# 3   1178         Data Engineer                    Data Center Engineer
# 4   1278        Cloud Engineer                 Infrastructure Engineer
#
#                       job_location              job_via job_schedule_type  \
# 0                        Australia  via BeBee Australia         Full-time
# 1            Sydney NSW, Australia         via LinkedIn         Full-time
# 2            Sydney NSW, Australia      via Trabajo.org         Full-time
# 3            Sydney NSW, Australia         via LinkedIn         Full-time
# 4  Fortitude Valley QLD, Australia         via LinkedIn         Full-time
#
#    job_work_from_home search_location     job_posted_date  \
# ...
