# %%
import pandas as pd
import numpy as np
from datasets import load_dataset
import matplotlib.pyplot as plt

# %%
#loading dataset 

dataset = load_dataset("lukebarousse/data_jobs")

data_jobs = dataset['train'].to_pandas()

data_jobs ["job_posted_date"] = pd.to_datetime(data_jobs.job_posted_date)

# %%
data_jobs.sample(10, random_state =34)
# Out:
#                   job_title_short  \
# 137303        Senior Data Analyst
# 146823               Data Analyst
# 212207               Data Analyst
# 135081               Data Analyst
# 737611              Data Engineer
# 27340           Software Engineer
# 306027           Business Analyst
# 488192               Data Analyst
# 63805              Data Scientist
# 670653  Machine Learning Engineer
#
#                                              job_title  \
# 137303                               Data Analyst, Sr.
# 146823                                 Data Analyst II
# 212207                                  Data Analyst I
# 135081              Application Support Data Analytics
# 737611                      Data AI Engineer (chatbot)
# 27340                    Software integration engineer
# 306027                                Business Analyst
# 488192                                    Data Analyst
# 63805                               Lead, Data Science
# 670653  Machine Learning Engineer ( Senior or Junior )
#
#                        job_location                              job_via  \
# 137303                   Orange, CA                            via Lensa
# 146823                   Austin, TX                      via Trabajo.org
# 212207                Deerfield, IL                         via JobSparx
# 135081      Buenos Aires, Argentina                            via BeBee
# 737611                     Anywhere                           via Indeed
# 27340                         Italy                            via BeBee
# 306027                        India                      via BeBee India
# 488192                    Hong Kong  via Trabajo.org - Job Search - Jobs
# 63805   Bengaluru, Karnataka, India                         via LinkedIn
# 670653    Neuilly-sur-Seine, France            via Welcome To The Jungle
#
#        job_schedule_type  job_work_from_home            search_location  \
# 137303         Full-time               False  California, United States
# 146823         Full-time               False       Texas, United States
# 212207         Full-time               False    Illinois, United States
# 135081         Full-time               False                  Argentina
# 737611         Full-time                True                Netherlands
# 27340          Full-time               False                      Italy
# 306027         Full-time               False                      India
# 488192         Full-time               False                  Hong Kong
# 63805          Full-time               False                      India
# 670653         Full-time               False                     France
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 137303 2023-02-09 08:01:05                  False                 False
# 146823 2023-03-28 08:03:18                   True                  True
# 212207 2023-05-01 22:02:14                  False                 False
# 135081 2023-10-16 08:45:40                   True                 False
# 737611 2023-08-30 21:39:51                  False                 False
# 27340  2023-07-12 13:14:18                  False                 False
# 306027 2023-05-25 17:25:27                  False                 False
# 488192 2023-04-03 11:51:48                   True                 False
# 63805  2023-11-12 06:08:58                  False                 False
# 670653 2023-02-13 10:31:48                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 137303  United States        None              NaN              NaN
# 146823  United States        None              NaN              NaN
# 212207  United States        None              NaN              NaN
# 135081      Argentina        None              NaN              NaN
# 737611    Netherlands        None              NaN              NaN
# 27340           Italy        None              NaN              NaN
# 306027          India        None              NaN              NaN
# 488192      Hong Kong        None              NaN              NaN
# 63805           India        None              NaN              NaN
# 670653         France        None              NaN              NaN
#
#              company_name                                         job_skills  \
# 137303    Government jobs  ['sql', 'visual basic', 'vba', 'excel', 'outlo...
# 146823     PDS Tech, Inc.                                          ['excel']
# 212207            Experis  ['sql', 'tableau', 'visio', 'word', 'powerpoin...
# 135081            Emprego  ['sql', 'nosql', 'python', 'elasticsearch', 'a...
# 737611   Apollo Solutions  ['python', 'go', 'aws', 'azure', 'databricks',...
# 27340       Kion Group AG                                               None
# 306027        intellijobs               ['sql', 'excel', 'power bi', 'flow']
# 488192  A.S. Watson Group                        ['python', 'sql', 'watson']
# 63805             Kyndryl  ['go', 'python', 'r', 'aws', 'pytorch', 'tenso...
# 670653            Reverso                                               None
#
#                                           job_type_skills
# 137303  {'analyst_tools': ['excel', 'outlook', 'powerp...
# 146823                       {'analyst_tools': ['excel']}
# 212207  {'analyst_tools': ['tableau', 'visio', 'word',...
# 135081  {'analyst_tools': ['splunk'], 'cloud': ['aws']...
# 737611  {'cloud': ['aws', 'azure', 'databricks'], 'lib...
# 27340                                                None
# 306027  {'analyst_tools': ['excel', 'power bi'], 'othe...
# 488192  {'cloud': ['watson'], 'programming': ['python'...
# 63805   {'cloud': ['aws'], 'libraries': ['pytorch', 't...
# 670653                                               None

# %%
new_data_jobs = data_jobs.copy()
